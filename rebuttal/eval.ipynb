# %%
from datasets import load_dataset
dataset = load_dataset("mikronai/VectorEdits")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# train-00000-of-00005.parquet:   0%|          | 0.00/67.8M [00:00<?, ?B/s]
# train-00001-of-00005.parquet:   0%|          | 0.00/23.6M [00:00<?, ?B/s]
# train-00002-of-00005.parquet:   0%|          | 0.00/42.6M [00:00<?, ?B/s]
# train-00003-of-00005.parquet:   0%|          | 0.00/68.6M [00:00<?, ?B/s]
# train-00004-of-00005.parquet:   0%|          | 0.00/70.0M [00:00<?, ?B/s]
# validation-00000-of-00001.parquet:   0%|          | 0.00/302k [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/2.03M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/269106 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/200 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2000 [00:00<?, ? examples/s]

# %%
test = dataset["test"]
print("Test size:", len(test))
# Out:
# Test size: 2000

# %%
from svgai.img import center_pad_image
from svgai.svg import render_fit
import matplotlib.pyplot as plt

page = 20
page_size = 20

for i in range(page * page_size, (page + 1) * page_size):
    item = test[i]
    image_1 = render_fit(item["item_1"]["item_svg"], 512, 512, background="white")
    image_1 = center_pad_image(image_1, 512, 512)
    image_2 = render_fit(item["item_2"]["item_svg"], 512, 512, background="white")
    image_2 = center_pad_image(image_2, 512, 512)

    # Create plot with two images side by side
    fig, ax = plt.subplots(1, 2, figsize=(10, 5))
    ax[0].imshow(image_1)
    ax[0].axis("off")
    ax[1].imshow(image_2)
    ax[1].axis("off")
    # add title
    fig.suptitle(item['instruction'])
